# %% [markdown]
# ### Background and Overview:
# The [MIMIC-III](https://mimic.mit.edu/about/mimic/) (Medical Information Mart for Intensive Care) Clinical Database is comprised of deidentified health-related data associated with over 40,000 patients (available through request). Its 26 tables have a vast amount of information on the patients who stayed in critical care units of the Beth Israel Deaconess Medical Center between 2001 and 2012 ranging from patient demographics to lab reports to detailed clinical notes.

# %% [markdown]
# #### Figure 1: Compares Structured Data's Values for Alive and Deceased Patients
# This analysis was done on 1,000 patients, with a 50/50 split between patients who were marked alive and those who were marked deceased. The feature vectors were created from the patients' data is comprised of structured data fields: the summed values of different labs, the counts of different diagnoses, and the counts of different medications prescribed (each different lab/diagnosis/medication is a its own feature).

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

from IPython.display import Image

# %%
"""NOTE: This code block is commented out because I have not uploaded data files or source code; it is only here to show to the process."""

# # Set up path/s to file/s
# path_to_data = '../data/'

# # Read data
# events = src.read_csv(path_to_data + 'events.csv')

# # Preprocess data
# filtered_events = src.filter_events(events)

# # Normalize and aggregate values for each events for each patient
# aggregated_events = src.aggregate_events(events)

# # Separate records for alive and deceased patients
# alive_agg_events = aggregated_events[aggregated_events['label'] != 1.0]
# deceased_agg_events = aggregated_events[aggregated_events['label'] == 1.0]
# Out:
# 'NOTE: This code block is commented out because I have not uploaded data files or source code; it is only here to show to the process.'

# %%
"""NOTE: This code block is also commented out as above; it is only here to show to the process."""

# # Plot the data
# bins = np.linspace(0, 1.0, 100)

# fig1 = plt.subplots()
# plt.hist(alive_agg_events['feature_value'], bins, alpha = 0.5, label='alive', 
#          histtype='bar', ec='grey')
# plt.hist(deceased_agg_events['feature_value'], bins, alpha = 0.5, label='deceased', 
#          histtype='bar', ec='grey')
# plt.ylabel("Frequency")
# plt.xlabel("Feature Values")
# plt.legend(loc='upper right')
# plt.title('Normalized Feature Values for Alive & Deceased Patients')

# plt.show()
# Out:
# 'NOTE: This code block is also commented out as above; it is only here to show to the process.'

# %%
Image(filename='Figure_1.png')
